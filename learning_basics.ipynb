# %%
import pandas as pd
from datetime import datetime

# %%
time_stamp = pd.Timestamp(datetime(2025, 9, 4))
pd.Timestamp('2025-09-04') == time_stamp
# Out:
# True

# %%
pd.Timestamp('2025-04-09') == time_stamp
# Out:
# False

# %%
time_stamp.year
# Out:
# 2025

# %%
time_stamp.day_name()
# Out:
# 'Thursday'

# %% [markdown]
# **Periods and Frequency**

# %%
period = pd.Period('2025-09')

# %%
period #default: month
# Out:
# Period('2025-09', 'M')

# %%
period.asfreq('D')
# Out:
# Period('2025-09-30', 'D')

# %%
period.to_timestamp()
# Out:
# Timestamp('2025-09-01 00:00:00')

# %%
period.to_timestamp().to_period('D')
# Out:
# Period('2025-09-01', 'D')

# %%
period
# Out:
# Period('2025-09', 'M')

# %%
period+4
# Out:
# Period('2026-01', 'M')

# %%
pd.Timestamp('2025-09-30').to_period(freq='M')+1
# Out:
# Period('2025-10', 'M')

# %% [markdown]
# **Sequence of dates and times**

# %%
index = pd.date_range(start='2025-09-04', periods=10, freq='h') #specify either an end date or number of periods

# %%
index
# Out:
# DatetimeIndex(['2025-09-04 00:00:00', '2025-09-04 01:00:00',
#                '2025-09-04 02:00:00', '2025-09-04 03:00:00',
#                '2025-09-04 04:00:00', '2025-09-04 05:00:00',
#                '2025-09-04 06:00:00', '2025-09-04 07:00:00',
#                '2025-09-04 08:00:00', '2025-09-04 09:00:00'],
#               dtype='datetime64[ns]', freq='h')

# %%
index.to_period()[0]
# Out:
# Period('2025-09-04 00:00', 'h')

# %%
pd.DataFrame({"data": index}).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   data    10 non-null     datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 212.0 bytes

# %%
import numpy as np
data = np.random.random(size=(10,2))

# %%
my_df = pd.DataFrame(data=data, index=index)

# %%
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10 entries, 2025-09-04 00:00:00 to 2025-09-04 09:00:00
# Freq: h
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       10 non-null     float64
#  1   1       10 non-null     float64
# dtypes: float64(2)
# memory usage: 240.0 bytes

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Create the range of dates here
seven_days = ____

# Iterate over the dates and print the number and name of the weekday
for day in ___:
    print(___.___, ___.___)
